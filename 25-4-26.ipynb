# %%
# iris dataset work

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import

# %%
dataset.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
SepalLengthCm = dataset["SepalLengthCm"]
SepalWidthCm = dataset["SepalWidthCm"]
PetalLengthCm = dataset["PetalLengthCm"]
PetalWidthCm = dataset["PetalWidthCm"]
IrisSetosa = (dataset["Species"] == "Iris-setosa")
IrisVersicolor =( dataset["Species"] == "Iris-versicolor")
IrisVirginica =( dataset["Species"] == "Iris-virginica")

# %%
plt.scatter(SepalLengthCm[:50],SepalWidthCm[:50],color="red",label="IrisSetosa")
plt.scatter(SepalLengthCm[51:100],SepalWidthCm[51:100],color="blue",label="IrisVersicolor")
plt.scatter(SepalLengthCm[101:],SepalWidthCm[101:],color="green",label="IrisVirginica")
plt.legend()
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
plt.scatter(PetalLengthCm[:50],PetalWidthCm[:50],color="red",label="IrisSetosa")
plt.scatter(PetalLengthCm[51:100],PetalWidthCm[51:100],color="blue",label="IrisVersicolor")
plt.scatter(PetalLengthCm[101:],PetalWidthCm[101:],color="green",label="IrisVirginica")
plt.legend()
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
# Out:
# Text(0, 0.5, 'PetalWidthCm')

# %%
plt.scatter(SepalLengthCm[:50],PetalLengthCm[:50],color="red",label="IrisSetosa")
plt.scatter(SepalLengthCm[51:100],PetalLengthCm[51:100],color="blue",label="IrisVersicolor")
plt.scatter(SepalLengthCm[101:],PetalLengthCm[101:],color="green",label="IrisVirginica")
plt.legend()
plt.xlabel("SepalLengthCm")
plt.ylabel("PetalLengthCm")
# Out:
# Text(0, 0.5, 'PetalLengthCm')

# %%
plt.scatter(PetalWidthCm[:50],SepalWidthCm[:50],color="red",label="IrisSetosa")
plt.scatter(PetalWidthCm[51:100],SepalWidthCm[51:100],color="blue",label="IrisVersicolor")
plt.scatter(PetalWidthCm[101:],SepalWidthCm[101:],color="green",label="IrisVirginica")
plt.legend()
plt.xlabel("PetalWidthCm")
plt.ylabel("SepalWidthCm")
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
plt.scatter(SepalLengthCm[:50],PetalWidthCm[:50],color="red",label="IrisSetosa")
plt.scatter(SepalLengthCm[51:100],PetalWidthCm[51:100],color="blue",label="IrisVersicolor")
plt.scatter(SepalLengthCm[101:],PetalWidthCm[101:],color="green",label="IrisVirginica")
plt.legend()
plt.xlabel("SepalLengthCm")
plt.ylabel("PetalWidthCm")
# Out:
# Text(0, 0.5, 'PetalWidthCm')

# %%
dataset = pd.read_csv("iris dataset.csv")
print(dataset.head())
np.unique_values(dataset["Species"])
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
plt.scatter(PetalLengthCm[:50],SepalWidthCm[:50],color="red",label="IrisSetosa")
plt.scatter(PetalLengthCm[51:100],SepalWidthCm[51:100],color="blue",label="IrisVersicolor")
plt.scatter(PetalLengthCm[101:],SepalWidthCm[101:],color="green",label="IrisVirginica")
plt.legend()
plt.xlabel("PetalLengthCm")
plt.ylabel("SepalWidthCm")
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
# SVM HERE

# %%
# from sklearn.svm import LinearSVC
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler

# %%
# X = IrisSetosa
# y = IrisVirginica
# svm_clf = Pipeline([
#  ("scaler", StandardScaler()),
#  ("linear_svc", LinearSVC(C=1, loss="hinge")),
#  ])
# # svm_clf.fit(X, y)

# %%
# iris = dataset
# X = iris[:, (2, 3)] # petal length, petal width
# y = (iris == 2).astype(np.float64) # Iris virginica
# svm_clf = Pipeline([
#  ("scaler", StandardScaler()),
#  ("linear_svc", LinearSVC(C=1, loss="hinge")),
#  ])
# svm_clf.fit(X, y)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC


df = pd.read_csv("iris dataset.csv")
df = df[df["Species"] != "Iris-setosa"]

X = df[["PetalLengthCm","PetalWidthCm"]].values
y = df["Species"]

le = LabelEncoder()
y = le.fit_transform(y)

model = SVC(kernel='linear')
model.fit(X, y)

x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
y_min, y_max = X[:,1].min()-1, X[:,1].max()+1

xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200),
                     np.linspace(y_min, y_max, 200))

Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3)

for i in range(len(le.classes_)):
    plt.scatter(X[y==i,0], X[y==i,1], label=le.classes_[i])

plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.title("SVM Decision Boundary (2 Species)")
plt.legend()

# %%
# plt.scatter(IrisSetosa["SepalLengthCm"],IrisVersicolor["SepalWidthCm"])
